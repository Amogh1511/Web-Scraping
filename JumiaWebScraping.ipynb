# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
jumia = requests.get('https://www.jumia.co.ke/all-products/')
jumia.content
# Out:
# b'<!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;max-width:60rem;padding-left:1.5rem}@media (width <= 720px){.main-content{margin-top:4rem}}.h2{font-size:1.5rem;font-weight:500;line-height:2.25rem}@media (width <= 720px){.h2{font-size:1.25rem;line-height:1.5rem}}#challenge-error-text{background-image:url(data:image/svg+xml;base64,...);background-repeat:no-repeat;background-size:contain;padding-left:34px}@media (prefers-color-scheme:dark){body{background-color:#222;color:#d9d9d9}}</style><meta http-equiv="refresh" content="360"></head><body><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script>(function(){window._cf_chl_opt={cvId: \'3\',cZone: "www.jumia.co.ke",cType: \'non-interactive\',cRay: \'937d7400f805a917\',cH: \'c01J9HM2gRLkTMPHNd.hAG02pSnFClyTfMF.9wD8lPU-1745915591-1.2.1.1-4IQMII.I9ns0H3lzTVvknbZcoJSGD0igdb18OngSsIar6oVLIZVh_kQzLlXP1sx_\',cUPMDTk: "\\/all-products\\/?__cf_chl_tk=Omif45QWLvtAKaXcEDg76uOvIxANACT8UYUlBfDqrpo-1745915591-1.0.1.1-AkNLN2JoQ2Cc3kKV1KNUBUyKqj.jHjHQVVdG1DNFAI8",cFPWv: \'g\',cITimeS: \'1745915591\',cTplC: 0,cTplV: 5,cTplB: \'cf\',cK: "unsupported_browser_beacon",fa: "\\/all-products\\/?__cf_chl_f_tk=Omif45QWLvtAKaXcEDg76uOvIxANACT8UYUlBfDqrpo-1745915591-1.0.1.1-AkNLN2JoQ2Cc3kKV1KNUBUyKqj.jHjHQVVdG1DNFAI8",md: "3Q3FzrzjpyyDZUQLVb.GeIqunk1f0dlbEioKJ69oKQQ-1745915591-1.2.1.1-iwy8QlgD2Ebqnf59489mEqsDfptSUdz9Yd6cimHP5Pb1TdnPnY7ZfecwGl5_AQ389A_Ye_klfv7lhwhpJtAQK1HG8eix4NuDV05DXRYRLBFi.e7JTkCCNng6gAkTlk5Zkf1Lh4BkOHcB6NNsJukVLVUcTpEkh.8Z28_rknBqEtpJnb4DmsjZZKcms7o7mBi11jLc4t6noIVVEAHem6lKsHyCgijX6kx1rFnKScyI_d8aZ6rhRHn.EzZ_spos43XzkjxuH9iAnBWN08f0apsH13MFCwyVeTu9cGp_gcdUPGNxd2_OFQ13vnBWSRtYbap4LYarlfgJcSO.uw_9rOZHTagAH0xM2qIwdTB6SKqDYZJVlmpt4WSPHaQ7I0ridmVcIaBK8_Nkm5Q4TJFTzZ3KdWrRdqU2rRr8cVJ9rHc6.p1rrWyMJ4iDlbEHIbFfeF7aALfRRP..6MT.lLA5JiVxXbyS_Q11F3DLQauzhsxoYeKnwbHKwBiBP2PguTPHcDqU.iK6J.9mfUuDf.54Uo8Btc.FedU7kls3hvmANUNxQWCqgFfPhkF6beLPmtFWXuj.7s7v1NuFRL9AOW3ms4jp8fmtOuRQyxxhFUMGjRaVAZDwYKxTxRtqYJwYaZJ_Q882R07J3Kya7ieC0USf9WEvI.gq9IY32A52kD6_B9G1Az0wmzLVqFIX_5046qBjYLRrW08w44p3SPUb9twMuM.p7JAHqSQrTTSlC7CZMJ2sazVmhH2QQ2gxINvYqWScsbRNQ6oJhhxcwNSxtESmft3Ay.NZLZtGTCkbkDvqql4SGc_zONQRZ5TJBrKZvKf9CJWiudmCV7zSXDLDCLgwfF0QoaYH4OGe8efetOCmGg_1hNW.pOI9eXjCYpB6oU7Mf8tsRS2LAfK2uqSrFqrDXjOkud9pI2LF6LkZ9fG3GqHZRhSyIyBTdh0UeYAowahm17YrUPRsgQM5VLcNLSjoYBgbKJy3bgaSnzahvIsaeXeifgunOyx78qnHj4xCWC88BS0KfAtCa86gn9H.3wWycBtgMIB6i.NrSFvVsSpBY9mZZwlWQbXF0coCYLQ6w5n7wJ9roixrLt.GNgUr1Tqo6DxNaMl.PrGeTrJhFJPbngC0l8hBPien8JV1DCHFsZH9LFs9",mdrd: "7mf8kxX_UWo9SrxePnJqZeahvplT0Ydhl9hMrS2buL8-1745915591-1.2.1.1-fFDN8igNfETrNQQqqLgPWjb.rU0oqUNusyeaQdQYOqGq58HRovXHXkcp22dIQIo9Z7nBrkn1JfLJaScNHgji9d8fRNrslRavknK3821jlH1JI79j6vY3Cxp14Mpd_KxAxWMoybqyihxWBDcPw4Ex7DN8TujSBXl_Uef7sWjZaMzR9D6c3SoVgGEYUiy6hwbR07UnaV32c1Ymn2tZKDs4rI9E90_Xm.2VucbFRGUwNXGARS.nsqE6f6Qlo8hqIn3wVHHmMOgWLVQhaymWJvENGJ6mqj7CBRcjEqnunceP6p2AG88aNpHKIXHL.3G27iWCCr.fwFlNvkBIgjbEzO0w4h5in5eTkuvSdlMtviL71nTbB5JXkFeuenyARDK_m9qPNGhuZLb0kWb9dcMNVv3lZYAVnWI7N.U92D7M_UEIe0a1zkx7qO74cSopzoa.VtjMAxv7.3JqWPJ96gR66K_H7u3Ia_aKppwc_w4f1RbiTWIrX5aITxGD6MKPk2nFRB1qZj8i5ZB.E1OVQA9tGGVh1tMn3pcTcSHm_.YzRyJleMV_Ra4zX.p5P97zxpXxx83uwD5f4.5jNIR.Wy4VFsDu_iZTXWw1AzGjakDsYazie5Y_GtPCeiWLY0i.Nau4HnxBJm5jz ...

# %%
#Creating List
name_info = []
price_info = []
rating_info = []

# %%
for page in range(1,11):
    link = "https://www.jumia.co.ke/all-products/" + "?page=" + str(page) + "#catalog.listing"
    url = requests.get(link)
    jumia_soup = BeautifulSoup(url.content, 'html.parser')
    products = jumia_soup.find_all('div', class_='info')

    print(f"Page {page}: Found {len(products)} products")  # Debug print

    for product in products:
        Name = product.find('h3', class_='name')
        Price = product.find('div', class_='prc')

        if Name and Price:
            Name = Name.text.replace('\n', '')
            Price = Price.text.replace('\n', '')

            try:
                Rating = product.find('div', class_='stars _s').text.replace('\n', '')
            except:
                Rating = 'None'

            name_info.append(Name)
            price_info.append(Price)
            rating_info.append(Rating)

            # Debug print for each product
            print(f"Appended: Name={Name}, Price={Price}, Rating={Rating}")
        else:
            print("Name or Price not found for a product")
# Print the lists once after collecting all data
print(name_info, price_info, rating_info)
# Out:
# Page 1: Found 0 products
# Page 2: Found 0 products
# Page 3: Found 0 products
# Page 4: Found 0 products
# Page 5: Found 0 products
# Page 6: Found 0 products
# Page 7: Found 0 products
# Page 8: Found 0 products
# Page 9: Found 0 products
# Page 10: Found 0 products
# [] [] []

# %%
val = {'Product Name' : name_info, 'Price' : price_info, 'Rating' : rating_info}
df = pd.DataFrame(val)
path = 'D:/Intern/Edu-Versity/Jumiaproducts.csv'
df.to_csv(path, index = False, encoding = 'utf-8')
print(f"Scraping completed. Data saved to {path}")
# Out:
# Scraping completed. Data saved to D:/Intern/Edu-Versity/Jumiaproducts.csv
